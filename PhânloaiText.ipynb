# %%
import pandas as pd
import numpy as np
from collections import Counter
from tensorflow import keras
import os
import matplotlib.pyplot as plt
import time
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df = pd.read_csv("Tweets.csv")

# %%
df.shape
# Out:
# (27481, 4)

# %%
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
print((df.sentiment == "neutral").sum())
print((df.sentiment == "negative").sum())
print((df.sentiment == "positive").sum())
# Out:
# 11118
# 7781
# 8582

# %%
import re
import string 

def remove_URL(text):
    if isinstance(text, str):
        url = re.compile(r"https?://\S+|www\.\S+")
        return url.sub(r"", text)
    else:
        return text

def remove_punct(text):
    if isinstance(text, str):
        translator = str.maketrans("", "", string.punctuation)
        return text.translate(translator)
    else: 
        return text

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
pattern = re.compile(r"https?://(\S+|www)\.\S+")
for t in df.text:
    matches = pattern.findall(t)
    for match in matches:
        print(t)
        print(match)
        print(pattern.sub(r"", t))
    if len(matches) > 0:
        break
# Out:
# http://www.dothebouncy.com/smf - some shameless plugging for the best Rangers forum on earth
# www.dothebouncy
#  - some shameless plugging for the best Rangers forum on earth

# %%
df["text"] = df.text.map(remove_URL)
df["text"] = df.text.map(remove_punct)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop = set(stopwords.words("english"))

def remove_stopwords(text):
    if isinstance(text, str):
        filtered_words = [word.lower() for word in text.split() if word.lower() not in stop]
        return " ".join(filtered_words)
    else:
        return text

df["text"] = df.text.map(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
df["text"] = df.text.map(remove_stopwords)

# %%
df.text
# Out:
# 0                                       id responded going
# 1                                  sooo sad miss san diego
# 2                                            boss bullying
# 3                                    interview leave alone
# 4                 sons couldnt put releases already bought
#                                ...
# 27476    wish could come see u denver husband lost job ...
# 27477    ive wondered rake client made clear net dont f...
# 27478    yay good enjoy break probably need hectic week...
# 27479                                                worth
# 27480                   flirting going atg smiles yay hugs
# Name: text, Length: 27481, dtype: object

# %%
from collections import Counter

def counter_word(text_col):
    count = Counter()
    for text in text_col.values:
        if isinstance(text, str):
            for word in text.split():
                count[word] +=1
    return count

counter = counter_word(df.text)

# %%
len(counter)
# Out:
# 27773

# %%
counter
# Out:
# Counter({'im': 3024,
#          'day': 2044,
#          'good': 1549,
#          'get': 1426,
#          'like': 1346,
#          'go': 1267,
#          'dont': 1200,
#          'love': 1122,
#          'work': 1112,
#          'going': 1096,
#          'today': 1096,
#          'got': 1073,
#          'cant': 1021,
#          'happy': 976,
#          'one': 971,
#          'lol': 949,
#          'time': 943,
#          'know': 932,
#          'u': 923,
#          'really': 908,
#          'back': 891,
#          'see': 797,
#          'well': 744,
#          'new': 740,
#          'night': 737,
#          'home': 717,
#          'mothers': 717,
#          'want': 714,
#          'think': 705,
#          'still': 679,
#          '2': 665,
#          'oh': 663,
#          'much': 659,
#          'thanks': 657,
#          'miss': 614,
#          'great': 611,
#          'hope': 589,
#          'last': 581,
#          'need': 570,
#          'morning': 556,
#          'haha': 555,
#          'thats': 551,
#          'ill': 534,
#          'fun': 527,
#          'feel': 519,
#          'would': 503,
#          'twitter': 501,
#          'wish': 501,
#          'tomorrow': 499,
#          'sorry': 475,
#          'sad': 474,
#          'bad': 474,
#          'didnt': 469,
#          'tonight': 459,
#          'right': 459,
#          'make': 444,
#          'gonna': 433,
#          'nice': 430,
#          'yeah': 425,
#          'week': 419,
#          'better': 417,
#          'though': 416,
#          '3': 409,
#          'sleep': 405,
#          'way': 404,
#          'come': 401,
#          'ive': 396,
#          'could': 391,
#          'getting': 388,
#          'weekend': 388,
#          'bed': 366,
#          'people': 364,
#          'next': 363,
#          'youre': 343,
#          'watching': 338,
#          'wait': 326,
#          'days': 324,
#          'hate': 324,
#          'school': 323,
#          'awesome': 323,
#          'say': 322,
#          'best': 307,
#          'thing': 303,
#          'long': 300,
#          'even': 299,
#          'little': 296,
#          'hey': 296,
#          'soon': 294,
#          'never': 293,
#          'wont': 292,
#          'show': 288,
#          'yes': 288,
#          'working': 285,
#          'thank': 283,
#          'ok': 280,
#          'sure': 270,
#          'take': 269,
#          'done': 266,
#          'mom': 266,
#          'cool': 265,
#          '4': 265,
#          'first': 261,
#          'look': 260,
#          'tired': 260,
#          'may': 258,
#          'friends': 257,
#          'feeling': 256,
#          'everyone': 255,
#          'us': 253,
#          'sick': 250,
#          'please': 250,
#          'always': 250,
#          'another': 250,
#          'wanna': 249,
#          'ur': 249,
#          'life': 248,
#          'guys': 246,
#          'already': 243,
#          'doesnt': 243,
#          'hours': 242,
#          'movie': 240,
#          'phone': 235,
#          'man': 234,
#          'something': 232,
#          'house': 231,
#          'ever': 229,
#          'watch': 226,
#          'find': 225,
#          'trying': 223,
#          'old': 222,
#          'made': 222,
#          'ready': 219,
#          'yet': 217,
#          'finally': 215,
#          'friday': 214,
#          'went': 214,
#          'pretty': 213,
#          'x': 213,
#          'yay': 212,
#          'girl': 208,
#          'thought': 207,
#          'left': 206,
#          'looking': 205,
#          'sucks': 204,
#          'away': 204,
#          'looks': 202,
#          'maybe': 201,
#          'follow': 201,
#          'big': 200,
#          'guess': 200,
#          'year': 198,
#          'bit': 198,
#          'live': 197,
#          'also': 196,
#          'let': 196,
#          'amazing': 196,
#          'missed': 192,
#          '1': 191,
#          'wow': 190,
#          'omg': 189,
#          'someone': 187,
#          'friend': 186,
#          'star': 186,
#          'things': 185,
#          'two': 185,
#          'keep': 184,
#          'said': 183,
#          'monday': 183,
#          'ugh': 182,
#          'saw': 181,
#          'try': 179,
#          'actually': 179,
#          'nothing': 178,
#          'hear': 177,
#          'job': 176,
#          'hard': 176,
#          'hot': 176,
#          'early': 175,
#          'start': 175,
#          'tweet': 173,
#          'world': 171,
#          'later': 170,
#          'bored': 170,
#          'glad': 170,
#          'gone': 169,
#          'hes': 168,
#          'check': 166,
#          'havent': 165,
#          'play': 165,
#          'tell': 165,
#          'birthday': 165,
#          'ya': 165,
#          'song': 164,
#          'call': 163,
#          'car': 162,
#          'id': 161,
#          'n': 161,
#          'isnt': 161,
#          'since': 161,
#          'rain': 161,
#          'baby': 160,
#          'makes': 160,
#          'till': 160,
#          'around': 160,
#          'late': 159,
#          'hi': 159,
#          'lost': 158,
#          'coming': 158,
#          'yesterday': 158,
#          'lot': 158,
#          'anything': 158,
#          'help': 157,
#          'read': 157,
#          'stuff': 155,
#          'sun': 155,
#          'excited': 155,
#          'head': 154,
#          'gotta': 153,
#          'waiting': 153,
#          'weather': 153,
#          'poor': 153,
#          'found': 153,
#          'put': 152,
#          'talk': 151,
#          'must': 149,
#          'party': 149,
#          'moms': 149,
#          'music': 148,
#          'hair': 148,
#          'family': 148,
#          'give': 148,
#          'aww': 148,
#          'almost': 148,
#          'cause': 147,
#          'making': 147,
#          '5': 147,
#          'might': 146,
#          'summer': 143,
#          'many': 143,
#          'god': 143,
#          'mean': 140,
#          'enjoy': 140,
#          'wasnt': 140,
#          'leave': 139,
#          'hurts': 138,
#          'least': 138,
#          'money': 137,
#          'tho': 137,
#          'missing': 137,
#          'coffee': 137,
#          'believe': 137,
#          'forward': 136,
#          'lunch': 136,
#          'far': 136,
#          'cold': 135,
#          'stop': 135,
#          'anyone': 134,
#          'whats': 134,
#          'funny': 133,
#          'listening': 132,
#          'end': 131,
#          'game': 131,
#          'thinking': 131,
#          'everything': 131,
#          'welcome': 131,
#          'shes': 130,
#          'sunday': 130,
#          'eat': 130,
#          'sounds': 129,
#          'stupid': 129,
#          'times': 129,
#          'without': 129,
#          'wanted': 128,
#          'use': 128,
#          'luck': 128,
#          'cute': 127,
#          'dinner': 126,
#          'beautiful': 126,
#          'playing': 124,
#          'totally': 124,
#          'finished': 124,
#          'mine': 123,
#          'probably': 123,
#          'theres': 120,
#          'couldnt': 119,
#          'enough': 119,
#          'followers': 119,
#          'woke': 118,
#          'kids': 117,
#          'buy': 117,
#          'wants': 117,
#          'free': 116,
#          'whole': 116,
#          'hour': 116,
#          'weeks': 116,
#          'place': 116,
#          'sweet': 116,
#          'food': 115,
#          'seen': 114,
#          'eating': 114,
#          'okay': 114,
#          'hell': 114,
#          'w': 113,
#          'took': 113,
#          'pic': 112,
#          'every': 111,
#          'outside': 111,
#          'lovely': 110,
#          'says': 109,
#          'ha': 109,
#          'sooo': 108,
#          'kinda': 108,
#          'hahaha': 106,
#          'years': 106,
#          'real': 105,
#          'office': 103,
#          'book': 103,
#          'anymore': 103,
#          'goodnight': 103,
#          'following': 102,
#          'ago': 102,
#          'class': 102,
#          'tv': 102,
#          'super': 102,
#          'room': 102,
#          'awww': 102,
#          'stuck': 101,
#          'came': 100,
#          'loved': 100,
#          'full': 100,
#          'taking': 100,
#          'r': 99,
#          'else': 98,
#          '10': 96,
#          'stay': 96,
#          'hit': 96,
#          'headache': 96,
#          'meet': 96,
#          'name': 96,
#          'hello': 96,
#          'wrong': 96,
#          'busy': 95,
#          'forgot': 95,
#          'saturday': 95,
#          'hopefully': 95,
#          'boo': 94,
#          'video': 94,
#          'gets': 94,
#          'seems': 94,
#          'dude': 93,
#          'used': 93,
#          'wars': 92,
#          'kind': 92,
#          'sitting': 92,
#          'guy': 92,
#          'online': 91,
#          'theyre': 91,
#          'girls': 91,
#          'idea': 91,
#          'lots': 91,
#          'able': 91,
#          'internet': 90,
#          'shopping': 90,
#          'dad': 90,
#          'broke': 90,
#          'b': 90,
#          'tweets': 89,
#          'crazy': 89,
#          'minutes': 88,
#          'holiday': 88,
#          'quite': 88,
#          'break': 88,
#          'mum': 87,
#          'trip': 87,
#          'talking': 87,
#          'either': 87,
#          'cry': 87,
#          'seeing': 87,
#          '6': 86,
#          'part': 86,
#          'mind': 86,
#          'post': 85,
#          'news': 85,
#          'remember': 85,
#          'awake': 85,
#          'dog': 85,
#          'instead': 85,
#          'run': 85,
#          'alone': 84,
#          'called': 84,
#          'iphone': 84,
#          'change': 84,
#          'trek': 84,
#          'rest': 84,
#          'cuz': 84,
#          'face': 83,
#          'evening': 83,
#          'feels': 82,
#          'starting': 81,
#          'watched': 81,
#          'ones': 81,
#          'hurt': 81,
#          'wonderful': 81,
#          'btw': 81,
#          'tried': 81,
#          'running': 80,
#          'drink': 80,
#          'bank': 80,
#          'win': 80,
#          'ah': 80,
#          'person': 80,
#          'send': 80,
#          'half': 80,
#          'computer': 79,
#          'facebook': 79,
#          'til': 79,
#          'heard': 79,
#          'soo': 78,
#          'concert': 78,
#          'picture': 78,
#          'goes': 78,
#          'lets': 77,
#          'dead': 77,
#          'writing': 77,
#          'told': 77,
#          'aw': 76,
#          'blog': 76,
#          'ask': 76,
#          'breakfast': 76,
#          'true': 76,
#          'loves': 76,
#          'hehe': 75,
#          'lucky': 75,
#          'fine': 75,
#          'needs': 75,
#          'fail': 75,
#          'perfect': 75,
#          'fan': 74,
#          'boy': 74,
#          '7': 74,
#          'drive': 74,
#          'lil': 74,
#          'month': 74,
#          'close': 74,
#          'move': 74,
#          'sleeping': 73,
#          'site': 73,
#          'bought': 72,
#          'high': 72,
#          'hoping': 72,
#          'yea': 72,
#          'ice': 72,
#          'turn': 72,
#          'pain': 72,
#          'sometimes': 72,
#          'started': 72,
#          'favorite': 71,
#          'beach': 71,
#          'email': 71,
#          'moment': 71,
#          'youtube': 71,
#          'raining': 71,
#          'la': 71,
#          'soooo': 70,
#          'lmao': 70,
#          'couple': 70,
#          'mommy': 70,
#          'hungry': 70,
#          'months': 70,
#          '8': 70,
#          'heading': 69,
#          'happened': 69,
#          'mother': 69,
#          'exam': 69,
#          'yall': 69,
#          'open': 68,
#          'problem': 68,
#          'bday': 68,
#          'goin': 68,
#          'supposed': 67,
#          'tickets': 67,
#          'set': 67,
#          'wake': 67,
#          'heart': 67,
#          'test': 66,
#          'boring': 66,
#          'shower': 66,
#          'definitely': 66,
#          'june': 66,
#          'leaving': 66,
#          'movies': 66,
#          'suck': 66,
#          'p': 65,
#          'catch': 65,
#          'sore': 65,
#          'vote': 65,
#          'anyway': 65,
#          'tea': 65,
#          'happen': 65,
#          'link': 65,
#          'account': 64,
#          'top': 64,
#          'comes': 64,
#          'youll': 64,
#          'sigh': 63,
#          'hang': 63,
#          'rock': 63,
#          'aint': 63,
#          'eyes': 63,
#          'arent': 63,
#          'gave': 63,
#          '4th': 63,
#          'reading': 63,
#          'dear': 62,
#          'asleep': 62,
#          'pictures': 62,
#          'saying': 62,
#          'city': 62,
#          'course': 62,
#          'cat': 62,
#          'dream': 62,
#          'bout': 61,
#          'means': 61,
#          'list': 61,
#          'care': 61,
#          'reason': 61,
#          'chocolate': 61,
#          'season': 61,
#          'less': 61,
#          'past': 60,
#          'cleaning': 60,
#          'write': 60,
#          'red': 60,
#          'flu': 60,
#          'songs': 60,
#          'nite': 60,
#          'short': 60,
#          'wishing': 60,
#          'spend': 60,
#          'sunny': 60,
#          'interesting': 59,
#          'pics': 59,
#          'fb': 59,
#          'jonas': 59,
#          'sadly': 59,
#          'photo': 59,
#          'final': 59,
#          '12': 59,
#          'drinking': 59,
#          'due': 59,
#          'special': 59,
#          'wouldnt': 59,
#          'meeting': 58,
#          'yep': 58,
#          'moving': 58,
#          'using': 58,
#          'together': 58,
#          'tour': 58,
#          'fast': 58,
#          'hugs': 58,
#          'forget': 57,
#          'fair': 57,
#          'knew': 57,
#          'xd': 57,
#          'reply': 56,
#          'text': 56,
#          'bring': 56,
#          'date': 56,
#          '30': 56,
#          'sound': 56,
#          'boys': 56,
#          'ppl': 56,
#          'water': 56,
#          'second': 56,
#          'card': 56,
#          'ipod': 55,
#          'jealous': 55,
#          'uk': 55,
#          'cream': 55,
#          'worth': 55,
#          'afternoon': 55,
#          'london': 55,
#          'mad': 55,
#          'seem': 55,
#          'cut': 54,
#          'fell': 54,
#          'unfortunately': 54,
#          'nope': 54,
#          'episode': 54,
#          'seriously': 54,
#          'driving': 54,
#          'chance': 54,
#          'cake': 53,
#          'exams': 53,
#          'congrats': 53,
#          'three': 53,
#          'died': 53,
#          'park': 53,
#          'broken': 53,
#          'spent': 53,
#          'bye': 53,
#          'liked': 53,
#          'town': 53,
#          'nap': 53,
#          'walk': 52,
#          'youve': 52,
#          'plans': 52,
#          'finish': 52,
#          'ahh': 52,
#          'rather': 51,
#          'add': 51,
#          'google': 51,
#          'learn': 51,
#          'mood': 51,
#          'warm': 51,
#          'different': 51,
#          'enjoying': 51,
#          'point': 51,
#          'wtf': 51,
#          'listen': 51,
#          'english': 50,
#          'garden': 50,
#          'meant': 50,
#          'laptop': 50,
#          'save': 50,
#          'weird': 50,
#          'everybody': 50,
#          'photos': 50,
#          'wedding': 50,
#          'slow': 50,
#          'brothers': 49,
#          '1st': 49,
#          'sister': 49,
#          'plus': 49,
#          'album': 49,
#          'ride': 48,
#          'works': 48,
#          'worry': 48,
#          'looked': 48,
#          'fall': 48,
#          'huge': 48,
#          'store': 48,
#          'side': 48,
#          'em': 48,
#          'worst': 48,
#          'c': 48,
#          'page': 48,
#          'shows': 48,
#          'pizza': 48,
#          'black': 47,
#          'agree': 47,
#          'clean': 47,
#          'bet': 47,
#          'bgt': 47,
#          'gym': 47,
#          'babe': 47,
#          'da': 47,
#          'sent': 47,
#          'bus': 47,
#          'needed': 47,
#          'message': 47,
#          'earlier': 47,
#          'slept': 46,
#          'living': 46,
#          'mr': 46,
#          'tweeting': 46,
#          'figure': 46,
#          'sat': 46,
#          'horrible': 46,
#          'white': 46,
#          'lady': 46,
#          'upset': 46,
#          'kid': 46,
#          'absolutely': 45,
#          'except': 45,
#          'yum': 45,
#          'fact': 45,
#          'windows': 45,
#          'wishes': 45,
#          'shame': 45,
#          'beer': 45,
#          'camera': 45,
#          'easy': 45,
#          'sunshine': 45,
#          'near': 45,
#          'played': 45,
#          'apparently': 45,
#          'story': 44,
#          'drunk': 44,
#          'word': 44,
#          '100': 44,
#          'ohh': 44,
#          'business': 44,
#          'brother': 44,
#          'especially': 44,
#          'understand': 44,
#          'hanging': 44,
#          'words': 44,
#          'throat': 43,
#          'bless': 43,
#          'pick': 43,
#          'study': 43,
#          'ate': 43,
#          'parents': 43,
#          'answer': 43,
#          'starts': 43,
#          'yummy': 43,
#          'update': 43,
#          'fans': 43,
#          'visit': 43,
#          'behind': 43,
#          'hows': 43,
#          'ahhh': 42,
#          'longer': 42,
#          'traffic': 42,
#          'thx': 42,
#          'die': 42,
#          'smile': 42,
#          'fantastic': 42,
#          'dreams': 42,
#          'wondering': 42,
#          'college': 42,
#          'middle': 42,
#          'cos': 42,
#          'updates': 41,
#          'hand': 41,
#          'wear': 41,
#          'inside': 41,
#          'relaxing': 41,
#          'dang': 41,
#          '15': 41,
#          'idk': 41,
#          'crying': 41,
#          'hmm': 41,
#          'number': 41,
#          'along': 41,
#          'loving': 41,
#          'cheese': 41,
#          'hug': 41,
#          'wine': 40,
#          'ran': 40,
#          'plan': 40,
#          'worse': 40,
#          'bc': 40,
#          'company': 40,
#          'lonely': 40,
#          'sign': 40,
#          'shoes': 40,
#          'blue': 40,
#          'dance': 40,
#          'bike': 40,
#          'itll': 40,
#          'club': 40,
#          'team': 40,
#          'project': 40,
#          'happens': 40,
#          'fingers': 39,
#          'graduation': 39,
#          'mums': 39,
#          'ouch': 39,
#          'hun': 39,
#          '20': 39,
#          'son': 39,
#          'small': 39,
#          'cannot': 39,
#          'officially': 39,
#          'ps': 39,
#          'air': 39,
#          'prom': 39,
#          'forever': 39,
#          'feet': 39,
#          'chat': 39,
#          'thinks': 39,
#          'gift': 39,
#          'snl': 39,
#          'line': 39,
#          'green': 39,
#          'worked': 38,
#          'huh': 38,
#          'safe': 38,
#          'sold': 38,
#          'luv': 38,
#          'hates': 38,
#          'join': 38,
#          'stomach': 38,
#          'chicken': 38,
#          'mac': 38,
#          'lazy': 38,
#          'cup': 38,
#          'nights': 38,
#          'via': 38,
#          'wonder': 37,
#          'none': 37,
#          'comment': 37,
#          'pool': 37,
#          'apple': 37,
#          'band': 37,
#          'exciting': 37,
#          'john': 37,
#          'radio': 37,
#          'guitar': 37,
#          'shop': 37,
#          'gutted': 37,
#          'lame': 37,
#          'swine': 37,
#          'revision': 37,
#          'exactly': 37,
#          'app': 36,
#          'shall': 36,
#          'etc': 36,
#          'hospital': 36,
#          'miles': 36,
#          'keeps': 36,
#          'decided': 36,
#          'pass': 36,
#          'realized': 36,
#          'version': 36,
#          'woo': 36,
#          'packing': 36,
#          'boyfriend': 36,
#          'quick': 36,
#          'clothes': 36,
#          'hubby': 36,
#          'appreciate': 36,
#          'chillin': 36,
#          'low': 35,
#          'fly': 35,
#          '2day': 35,
#          'hahah': 35,
#          'homework': 35,
#          'sleepy': 35,
#          'shirt': 35,
#          'flight': 35,
#          'others': 35,
#          'messages': 35,
#          'train': 35,
#          'although': 35,
#          'body': 35,
#          'wife': 35,
#          'completely': 35,
#          'moved': 35,
#          'bbq': 35,
#          'min': 35,
#          'problems': 35,
#          'taken': 35,
#          'rainy': 35,
#          'french': 34,
#          'whatever': 34,
#          'screen': 34,
#          'fix': 34,
#          'felt': 34,
#          'moon': 34,
#          'posted': 34,
#          'vegas': 34,
#          'rip': 34,
#          'dm': 34,
#          'church': 34,
#          'takes': 34,
#          'share': 34,
#          'tom': 34,
#          'dvd': 34,
#          '11': 34,
#          'sing': 34,
#          'closed': 34,
#          'case': 33,
#          'matter': 33,
#          'sending': 33,
#          'met': 33,
#          'stopped': 33,
#          'usually': 33,
#          'legs': 33,
#          'support': 33,
#          'mama': 33,
#          'alot': 33,
#          'men': 33,
#          'quiet': 33,
#          'paper': 33,
#          'studying': 33,
#          'somewhere': 33,
#          'dress': 33,
#          'dark': 33,
#          'single': 33,
#          'group': 32,
#          'walking': 32,
#          'dogs': 32,
#          'film': 32,
#          'singing': 32,
#          'wearing': 32,
#          'starbucks': 32,
#          'alright': 32,
#          'deal': 32,
#          'staying': 32,
#          'justin': 32,
#          'math': 32,
#          'tuesday': 32,
#          'videos': 32,
#          'ooh': 32,
#          'david': 32,
#          'front': 32,
#          'bummed': 32,
#          'tummy': 32,
#          'xoxo': 32,
#          'round': 31,
#          'extra': 31,
#          'followed': 31,
#          'sit': 31,
#          '2nd': 31,
#          'proud': 31,
#          'waking': 31,
#          'twilight': 31,
#          'public': 31,
#          'hannah': 31,
#          'thursday': 31,
#          '9': 31,
#          'checked': 31,
#          'goodbye': 31,
#          'sexy': 31,
#          'service': 31,
#          'bro': 31,
#          'indeed': 31,
#          'power': 30,
#          'nyc': 30,
#          'cd': 30,
#          'beat': 30,
#          'myspace': 30,
#          'note': 30,
#          'gorgeous': 30,
#          'mate': 30,
#          '25': 30,
#          'kill': 30,
#          'giving': 30,
#          'wheres': 30,
#          'web': 30,
#          'count': 30,
#          'airport': 30,
#          'jus': 30,
#          'coz': 30,
#          'bloody': 30,
#          'become': 30,
#          'games': 30,
#          'july': 30,
#          'ima': 30,
#          'yo': 30,
#          'website': 30,
#          'annoying': 29,
#          'machine': 29,
#          'wolverine': 29,
#          'disappointed': 29,
#          'failed': 29,
#          'pay': 29,
#          'fam': 29,
#          'shot': 29,
#          'feelin': 29,
#          'k': 29,
#          'tonite': 29,
#          'caught': 29,
#          'scared': 29,
#          'random': 29,
#          'congratulations': 29,
#          'enjoyed': 29,
#          'question': 29,
#          'copy': 29,
#          'calling': 29,
#          'paid': 29,
#          'talent': 29,
#          'changed': 29,
#          'books': 29,
#          'gettin': 29,
#          'mobile': 29,
#          'taylor': 28,
#          'voice': 28,
#          'minute': 28,
#          'ticket': 28,
#          'itunes': 28,
#          'prob': 28,
#          'dads': 28,
#          'mention': 28,
#          'l': 28,
#          'ended': 28,
#          'follower': 28,
#          'cats': 28,
#          'door': 28,
#          'classes': 28,
#          'iï¿½m': 28,
#          'young': 28,
#          'anytime': 28,
#          'blood': 28,
#          'race': 28,
#          'awful': 28,
#          'yr': 28,
#          'ff': 28,
#          'eh': 28,
#          'milk': 28,
#          'scary': 28,
#          'currently': 28,
#          'ages': 28,
#          'interview': 27,
#          'available': 27,
#          'bag': 27,
#          'cheers': 27,
#          ...})

# %%
counter.most_common(5)
# Out:
# [('im', 3024), ('day', 2044), ('good', 1549), ('get', 1426), ('like', 1346)]

# %%
num_unique_words = len(counter)

# %%
train_size = int(df.shape[0] * 0.8)
train_df = df[:train_size]
val_df = df[train_size:]

# %%
train_sentences = train_df.text.to_numpy()
train_labels = train_df.sentiment.to_numpy()
val_sentences = val_df.text.to_numpy()
val_labels = val_df.sentiment.to_numpy()

# %%
train_sentences.shape, val_sentences.shape
# Out:
# ((21984,), (5497,))

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
train_sentences = [text for text in train_sentences if isinstance(text, str)]
tokenizer = Tokenizer(num_words=num_unique_words)
tokenizer.fit_on_texts(train_sentences) 
word_index = tokenizer.word_index

# %%
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'im': 1,
#  'day': 2,
#  'good': 3,
#  'get': 4,
#  'like': 5,
#  'go': 6,
#  'dont': 7,
#  'love': 8,
#  'going': 9,
#  'today': 10,
#  'work': 11,
#  'got': 12,
#  'cant': 13,
#  'one': 14,
#  'happy': 15,
#  'lol': 16,
#  'know': 17,
#  'u': 18,
#  'time': 19,
#  'back': 20,
#  'really': 21,
#  'see': 22,
#  'well': 23,
#  'new': 24,
#  'home': 25,
#  'think': 26,
#  'night': 27,
#  'want': 28,
#  'mothers': 29,
#  'still': 30,
#  'thanks': 31,
#  '2': 32,
#  'oh': 33,
#  'much': 34,
#  'great': 35,
#  'hope': 36,
#  'miss': 37,
#  'need': 38,
#  'last': 39,
#  'morning': 40,
#  'thats': 41,
#  'haha': 42,
#  'ill': 43,
#  'fun': 44,
#  'feel': 45,
#  'tomorrow': 46,
#  'twitter': 47,
#  'wish': 48,
#  'would': 49,
#  'didnt': 50,
#  'sad': 51,
#  'sorry': 52,
#  'bad': 53,
#  'tonight': 54,
#  'right': 55,
#  'week': 56,
#  'nice': 57,
#  'yeah': 58,
#  'gonna': 59,
#  'better': 60,
#  'make': 61,
#  'though': 62,
#  'way': 63,
#  '3': 64,
#  'ive': 65,
#  'sleep': 66,
#  'come': 67,
#  'could': 68,
#  'weekend': 69,
#  'getting': 70,
#  'bed': 71,
#  'watching': 72,
#  'next': 73,
#  'people': 74,
#  'youre': 75,
#  'awesome': 76,
#  'wait': 77,
#  'school': 78,
#  'days': 79,
#  'hate': 80,
#  'say': 81,
#  'best': 82,
#  'thing': 83,
#  'yes': 84,
#  'even': 85,
#  'thank': 86,
#  'show': 87,
#  'never': 88,
#  'wont': 89,
#  'working': 90,
#  'ok': 91,
#  'cool': 92,
#  'long': 93,
#  'look': 94,
#  'little': 95,
#  'soon': 96,
#  'hey': 97,
#  'everyone': 98,
#  'done': 99,
#  '4': 100,
#  'take': 101,
#  'friends': 102,
#  'us': 103,
#  'may': 104,
#  'mom': 105,
#  'wanna': 106,
#  'sure': 107,
#  'sick': 108,
#  'feeling': 109,
#  'life': 110,
#  'ur': 111,
#  'tired': 112,
#  'first': 113,
#  'another': 114,
#  'always': 115,
#  'already': 116,
#  'guys': 117,
#  'please': 118,
#  'doesnt': 119,
#  'movie': 120,
#  'phone': 121,
#  'house': 122,
#  'hours': 123,
#  'something': 124,
#  'watch': 125,
#  'trying': 126,
#  'find': 127,
#  'old': 128,
#  'ever': 129,
#  'man': 130,
#  'yet': 131,
#  'made': 132,
#  'went': 133,
#  'pretty': 134,
#  'looking': 135,
#  'friday': 136,
#  'ready': 137,
#  'x': 138,
#  'looks': 139,
#  'yay': 140,
#  'sucks': 141,
#  'bit': 142,
#  'thought': 143,
#  'girl': 144,
#  'follow': 145,
#  'guess': 146,
#  'away': 147,
#  'finally': 148,
#  'amazing': 149,
#  'big': 150,
#  'maybe': 151,
#  'left': 152,
#  'also': 153,
#  'live': 154,
#  'star': 155,
#  'omg': 156,
#  'ugh': 157,
#  'wow': 158,
#  'things': 159,
#  '1': 160,
#  'friend': 161,
#  'saw': 162,
#  'missed': 163,
#  'let': 164,
#  'year': 165,
#  'start': 166,
#  'hot': 167,
#  'monday': 168,
#  'hear': 169,
#  'someone': 170,
#  'nothing': 171,
#  'hard': 172,
#  'keep': 173,
#  'said': 174,
#  'two': 175,
#  'around': 176,
#  'gone': 177,
#  'actually': 178,
#  'id': 179,
#  'tweet': 180,
#  'havent': 181,
#  'job': 182,
#  'early': 183,
#  'till': 184,
#  'lost': 185,
#  'hes': 186,
#  'check': 187,
#  'tell': 188,
#  'rain': 189,
#  'song': 190,
#  'later': 191,
#  'birthday': 192,
#  'car': 193,
#  'world': 194,
#  'try': 195,
#  'play': 196,
#  'glad': 197,
#  'ya': 198,
#  'bored': 199,
#  'baby': 200,
#  'cause': 201,
#  'help': 202,
#  'yesterday': 203,
#  'isnt': 204,
#  'found': 205,
#  'music': 206,
#  'since': 207,
#  'anything': 208,
#  'hair': 209,
#  'making': 210,
#  'talk': 211,
#  'makes': 212,
#  'waiting': 213,
#  'late': 214,
#  'n': 215,
#  '5': 216,
#  'put': 217,
#  'stuff': 218,
#  'hi': 219,
#  'read': 220,
#  'sun': 221,
#  'lot': 222,
#  'family': 223,
#  'weather': 224,
#  'call': 225,
#  'almost': 226,
#  'hurts': 227,
#  'aww': 228,
#  'coming': 229,
#  'anyone': 230,
#  'least': 231,
#  'head': 232,
#  'excited': 233,
#  'moms': 234,
#  'lunch': 235,
#  'party': 236,
#  'summer': 237,
#  'many': 238,
#  'might': 239,
#  'must': 240,
#  'missing': 241,
#  'give': 242,
#  'leave': 243,
#  'gotta': 244,
#  'wasnt': 245,
#  'funny': 246,
#  'forward': 247,
#  'money': 248,
#  'whats': 249,
#  'poor': 250,
#  'everything': 251,
#  'believe': 252,
#  'end': 253,
#  'cute': 254,
#  'enjoy': 255,
#  'sounds': 256,
#  'sunday': 257,
#  'cold': 258,
#  'stop': 259,
#  'shes': 260,
#  'listening': 261,
#  'mean': 262,
#  'finished': 263,
#  'tho': 264,
#  'god': 265,
#  'use': 266,
#  'mine': 267,
#  'far': 268,
#  'without': 269,
#  'game': 270,
#  'coffee': 271,
#  'dinner': 272,
#  'wanted': 273,
#  'times': 274,
#  'buy': 275,
#  'totally': 276,
#  'eat': 277,
#  'thinking': 278,
#  'luck': 279,
#  'probably': 280,
#  'stupid': 281,
#  'couldnt': 282,
#  'welcome': 283,
#  'theres': 284,
#  'hour': 285,
#  'woke': 286,
#  'wants': 287,
#  'playing': 288,
#  'kids': 289,
#  'beautiful': 290,
#  'free': 291,
#  'enough': 292,
#  'okay': 293,
#  'followers': 294,
#  'sweet': 295,
#  'ha': 296,
#  'outside': 297,
#  'took': 298,
#  'weeks': 299,
#  'seen': 300,
#  'hell': 301,
#  'eating': 302,
#  'food': 303,
#  'w': 304,
#  'sooo': 305,
#  'hahaha': 306,
#  'years': 307,
#  'whole': 308,
#  'place': 309,
#  'room': 310,
#  'pic': 311,
#  'lovely': 312,
#  'came': 313,
#  'real': 314,
#  'stuck': 315,
#  'awww': 316,
#  'says': 317,
#  'following': 318,
#  'loved': 319,
#  'goodnight': 320,
#  'else': 321,
#  'hit': 322,
#  'office': 323,
#  'saturday': 324,
#  'taking': 325,
#  'anymore': 326,
#  'kinda': 327,
#  '10': 328,
#  'girls': 329,
#  'book': 330,
#  'name': 331,
#  'every': 332,
#  'headache': 333,
#  'r': 334,
#  'tv': 335,
#  'online': 336,
#  'video': 337,
#  'forgot': 338,
#  'ago': 339,
#  'class': 340,
#  'super': 341,
#  'able': 342,
#  'used': 343,
#  'wars': 344,
#  'gets': 345,
#  'theyre': 346,
#  'holiday': 347,
#  'full': 348,
#  'wrong': 349,
#  'boo': 350,
#  'seems': 351,
#  'mind': 352,
#  'sitting': 353,
#  'alone': 354,
#  'busy': 355,
#  'stay': 356,
#  'dad': 357,
#  'talking': 358,
#  'hopefully': 359,
#  'internet': 360,
#  'minutes': 361,
#  'quite': 362,
#  'dude': 363,
#  'news': 364,
#  'seeing': 365,
#  'broke': 366,
#  'idea': 367,
#  'kind': 368,
#  'hello': 369,
#  'b': 370,
#  'guy': 371,
#  'called': 372,
#  'shopping': 373,
#  'trip': 374,
#  'either': 375,
#  'rest': 376,
#  'crazy': 377,
#  'iphone': 378,
#  'trek': 379,
#  'remember': 380,
#  'run': 381,
#  'mum': 382,
#  'post': 383,
#  'tweets': 384,
#  '6': 385,
#  'part': 386,
#  'person': 387,
#  'dog': 388,
#  'fail': 389,
#  'tried': 390,
#  'cry': 391,
#  'meet': 392,
#  'break': 393,
#  'face': 394,
#  'evening': 395,
#  'cuz': 396,
#  'drink': 397,
#  'blog': 398,
#  'win': 399,
#  'lil': 400,
#  'bank': 401,
#  'soo': 402,
#  'lots': 403,
#  'lucky': 404,
#  'starting': 405,
#  'fine': 406,
#  'breakfast': 407,
#  'loves': 408,
#  'change': 409,
#  'ask': 410,
#  'ah': 411,
#  'hurt': 412,
#  'heard': 413,
#  'send': 414,
#  'running': 415,
#  'hoping': 416,
#  'til': 417,
#  '7': 418,
#  'watched': 419,
#  'half': 420,
#  'goes': 421,
#  'computer': 422,
#  'ice': 423,
#  'ones': 424,
#  'pain': 425,
#  'writing': 426,
#  'wonderful': 427,
#  'instead': 428,
#  'site': 429,
#  'boy': 430,
#  'lets': 431,
#  'turn': 432,
#  'mommy': 433,
#  'needs': 434,
#  'soooo': 435,
#  'sleeping': 436,
#  'heading': 437,
#  'true': 438,
#  'btw': 439,
#  'youtube': 440,
#  'perfect': 441,
#  'bought': 442,
#  'high': 443,
#  'hehe': 444,
#  'aw': 445,
#  'beach': 446,
#  'told': 447,
#  'tea': 448,
#  'picture': 449,
#  'feels': 450,
#  'started': 451,
#  'raining': 452,
#  'tickets': 453,
#  'lmao': 454,
#  'bday': 455,
#  'shower': 456,
#  'definitely': 457,
#  'awake': 458,
#  '8': 459,
#  'test': 460,
#  'fan': 461,
#  'favorite': 462,
#  'email': 463,
#  'drive': 464,
#  'couple': 465,
#  'moment': 466,
#  'move': 467,
#  'heart': 468,
#  'supposed': 469,
#  'concert': 470,
#  'goin': 471,
#  'wake': 472,
#  'month': 473,
#  'boring': 474,
#  'aint': 475,
#  'arent': 476,
#  'mother': 477,
#  'link': 478,
#  'suck': 479,
#  'cleaning': 480,
#  'facebook': 481,
#  'account': 482,
#  'dead': 483,
#  'anyway': 484,
#  'comes': 485,
#  'wishing': 486,
#  'pictures': 487,
#  'yall': 488,
#  'care': 489,
#  'cat': 490,
#  'sigh': 491,
#  'interesting': 492,
#  'asleep': 493,
#  'set': 494,
#  'p': 495,
#  'fell': 496,
#  'means': 497,
#  'sometimes': 498,
#  'happen': 499,
#  'months': 500,
#  'final': 501,
#  'drinking': 502,
#  'water': 503,
#  'yea': 504,
#  'problem': 505,
#  'text': 506,
#  'nite': 507,
#  'jonas': 508,
#  'top': 509,
#  'happened': 510,
#  'sadly': 511,
#  'rock': 512,
#  'close': 513,
#  'exam': 514,
#  'leaving': 515,
#  'tour': 516,
#  '12': 517,
#  'movies': 518,
#  'fast': 519,
#  'reading': 520,
#  'la': 521,
#  'dear': 522,
#  'red': 523,
#  'flu': 524,
#  'hang': 525,
#  'vote': 526,
#  'hungry': 527,
#  'june': 528,
#  'sunny': 529,
#  '4th': 530,
#  'ppl': 531,
#  'course': 532,
#  'season': 533,
#  'bout': 534,
#  'catch': 535,
#  'songs': 536,
#  'short': 537,
#  'meeting': 538,
#  'youll': 539,
#  'boys': 540,
#  'chocolate': 541,
#  'less': 542,
#  'dream': 543,
#  'pics': 544,
#  'open': 545,
#  'bring': 546,
#  'park': 547,
#  'moving': 548,
#  'using': 549,
#  'afternoon': 550,
#  'spend': 551,
#  'list': 552,
#  'due': 553,
#  'past': 554,
#  'write': 555,
#  'fb': 556,
#  'brothers': 557,
#  'seriously': 558,
#  'date': 559,
#  'eyes': 560,
#  'mad': 561,
#  'gave': 562,
#  'city': 563,
#  'ipod': 564,
#  'unfortunately': 565,
#  'episode': 566,
#  'worth': 567,
#  'everybody': 568,
#  'sound': 569,
#  'second': 570,
#  'cut': 571,
#  'cream': 572,
#  'sore': 573,
#  'youve': 574,
#  'driving': 575,
#  '30': 576,
#  'together': 577,
#  'knew': 578,
#  'enjoying': 579,
#  'cake': 580,
#  'jealous': 581,
#  'forget': 582,
#  'yep': 583,
#  'fair': 584,
#  'london': 585,
#  '1st': 586,
#  'reason': 587,
#  'wedding': 588,
#  'xd': 589,
#  'plus': 590,
#  'card': 591,
#  'liked': 592,
#  'nap': 593,
#  'works': 594,
#  'exams': 595,
#  'garden': 596,
#  'looked': 597,
#  'meant': 598,
#  'learn': 599,
#  'agree': 600,
#  'plans': 601,
#  'weird': 602,
#  'broken': 603,
#  'saying': 604,
#  'hugs': 605,
#  'apparently': 606,
#  'wouldnt': 607,
#  'ride': 608,
#  'uk': 609,
#  'congrats': 610,
#  'mood': 611,
#  'warm': 612,
#  'photo': 613,
#  'easy': 614,
#  'chance': 615,
#  'worst': 616,
#  'spent': 617,
#  'page': 618,
#  'sent': 619,
#  'bus': 620,
#  'message': 621,
#  'ahh': 622,
#  'special': 623,
#  'rather': 624,
#  'reply': 625,
#  'english': 626,
#  'walk': 627,
#  'nope': 628,
#  'huge': 629,
#  'died': 630,
#  'windows': 631,
#  'side': 632,
#  'em': 633,
#  'figure': 634,
#  'yummy': 635,
#  'sat': 636,
#  'photos': 637,
#  'sister': 638,
#  'point': 639,
#  'wtf': 640,
#  'except': 641,
#  'finish': 642,
#  'gym': 643,
#  'babe': 644,
#  'da': 645,
#  'bye': 646,
#  'lady': 647,
#  'town': 648,
#  'add': 649,
#  'tweeting': 650,
#  'fall': 651,
#  'yum': 652,
#  'clean': 653,
#  'different': 654,
#  'c': 655,
#  'loving': 656,
#  'kid': 657,
#  'earlier': 658,
#  'story': 659,
#  'slept': 660,
#  'drunk': 661,
#  'black': 662,
#  'worry': 663,
#  'word': 664,
#  'longer': 665,
#  'google': 666,
#  'store': 667,
#  'fact': 668,
#  'ohh': 669,
#  'beer': 670,
#  'business': 671,
#  'save': 672,
#  'hates': 673,
#  'bet': 674,
#  'especially': 675,
#  'understand': 676,
#  'pizza': 677,
#  'hanging': 678,
#  'needed': 679,
#  'listen': 680,
#  'album': 681,
#  'living': 682,
#  'shame': 683,
#  'exciting': 684,
#  'dreams': 685,
#  'shows': 686,
#  'seem': 687,
#  'wear': 688,
#  'absolutely': 689,
#  'bless': 690,
#  'sold': 691,
#  'laptop': 692,
#  '100': 693,
#  'pick': 694,
#  'study': 695,
#  'die': 696,
#  'wishes': 697,
#  'officially': 698,
#  'parents': 699,
#  'forever': 700,
#  '15': 701,
#  'chat': 702,
#  'starts': 703,
#  'chicken': 704,
#  'update': 705,
#  'fans': 706,
#  'visit': 707,
#  'white': 708,
#  'club': 709,
#  'ran': 710,
#  'mums': 711,
#  'throat': 712,
#  'three': 713,
#  '20': 714,
#  'thx': 715,
#  'ate': 716,
#  'relaxing': 717,
#  'ps': 718,
#  'smile': 719,
#  'camera': 720,
#  'brother': 721,
#  'answer': 722,
#  'bgt': 723,
#  'along': 724,
#  'hows': 725,
#  'played': 726,
#  'nights': 727,
#  'happens': 728,
#  'updates': 729,
#  'ahhh': 730,
#  'graduation': 731,
#  'hand': 732,
#  'mr': 733,
#  'apple': 734,
#  'fantastic': 735,
#  'company': 736,
#  'idk': 737,
#  'sign': 738,
#  'wondering': 739,
#  'college': 740,
#  'hmm': 741,
#  'near': 742,
#  'horrible': 743,
#  'cos': 744,
#  'taken': 745,
#  'low': 746,
#  'keeps': 747,
#  'plan': 748,
#  'small': 749,
#  'inside': 750,
#  'cannot': 751,
#  'dang': 752,
#  'prom': 753,
#  'quick': 754,
#  'sunshine': 755,
#  'stomach': 756,
#  'bike': 757,
#  'slow': 758,
#  'middle': 759,
#  'exactly': 760,
#  'project': 761,
#  'fingers': 762,
#  'shall': 763,
#  'band': 764,
#  'packing': 765,
#  'join': 766,
#  'church': 767,
#  'dance': 768,
#  'itll': 769,
#  'cup': 770,
#  'behind': 771,
#  'line': 772,
#  'revision': 773,
#  'hug': 774,
#  'via': 775,
#  'etc': 776,
#  'hun': 777,
#  'fly': 778,
#  'hahah': 779,
#  'traffic': 780,
#  'sleepy': 781,
#  'screen': 782,
#  'film': 783,
#  'usually': 784,
#  'radio': 785,
#  'shoes': 786,
#  'completely': 787,
#  'lazy': 788,
#  'shop': 789,
#  'snl': 790,
#  'bbq': 791,
#  'dress': 792,
#  'upset': 793,
#  '11': 794,
#  'front': 795,
#  'green': 796,
#  'team': 797,
#  'wine': 798,
#  'none': 799,
#  'huh': 800,
#  'son': 801,
#  'homework': 802,
#  'pass': 803,
#  'realized': 804,
#  'messages': 805,
#  'version': 806,
#  'woo': 807,
#  'air': 808,
#  'feet': 809,
#  'quiet': 810,
#  'train': 811,
#  'although': 812,
#  'body': 813,
#  'crying': 814,
#  'wife': 815,
#  'gutted': 816,
#  'lame': 817,
#  'dvd': 818,
#  'ooh': 819,
#  'words': 820,
#  'problems': 821,
#  'single': 822,
#  'rainy': 823,
#  'app': 824,
#  'hospital': 825,
#  'ouch': 826,
#  'safe': 827,
#  'pool': 828,
#  'luv': 829,
#  'bc': 830,
#  'sit': 831,
#  'met': 832,
#  'mama': 833,
#  'lonely': 834,
#  'thinks': 835,
#  'hubby': 836,
#  'dm': 837,
#  'starbucks': 838,
#  'blue': 839,
#  'moved': 840,
#  'takes': 841,
#  'number': 842,
#  'math': 843,
#  'july': 844,
#  'appreciate': 845,
#  'nyc': 846,
#  'wonder': 847,
#  'decided': 848,
#  'worse': 849,
#  'followed': 850,
#  'shirt': 851,
#  'felt': 852,
#  'others': 853,
#  'k': 854,
#  'boyfriend': 855,
#  'singing': 856,
#  'clothes': 857,
#  'men': 858,
#  'vegas': 859,
#  'rip': 860,
#  'question': 861,
#  'mac': 862,
#  'airport': 863,
#  'gift': 864,
#  'tuesday': 865,
#  'cheese': 866,
#  'ima': 867,
#  'tummy': 868,
#  'case': 869,
#  'miles': 870,
#  'annoying': 871,
#  'comment': 872,
#  'french': 873,
#  'whatever': 874,
#  'mention': 875,
#  'ended': 876,
#  'flight': 877,
#  'feelin': 878,
#  'kill': 879,
#  'support': 880,
#  'enjoyed': 881,
#  'posted': 882,
#  'thursday': 883,
#  'checked': 884,
#  'justin': 885,
#  'share': 886,
#  'swine': 887,
#  'somewhere': 888,
#  'videos': 889,
#  'dancing': 890,
#  'min': 891,
#  'yo': 892,
#  'currently': 893,
#  'sing': 894,
#  'extra': 895,
#  'ticket': 896,
#  'dads': 897,
#  'matter': 898,
#  'beat': 899,
#  '2day': 900,
#  'walking': 901,
#  'fix': 902,
#  'fam': 903,
#  'mate': 904,
#  'spending': 905,
#  'john': 906,
#  'legs': 907,
#  'alot': 908,
#  'classes': 909,
#  'race': 910,
#  'alright': 911,
#  'public': 912,
#  'hannah': 913,
#  'guitar': 914,
#  'studying': 915,
#  'bloody': 916,
#  'become': 917,
#  'sexy': 918,
#  'paid': 919,
#  'tom': 920,
#  'dark': 921,
#  'ages': 922,
#  'bummed': 923,
#  'bro': 924,
#  'voice': 925,
#  'available': 926,
#  'round': 927,
#  'itunes': 928,
#  'group': 929,
#  'suppose': 930,
#  'l': 931,
#  'fixed': 932,
#  'lately': 933,
#  'follower': 934,
#  'gorgeous': 935,
#  'gig': 936,
#  'dogs': 937,
#  'tonite': 938,
#  'likes': 939,
#  'moon': 940,
#  'afraid': 941,
#  'followfriday': 942,
#  'web': 943,
#  'count': 944,
#  'deal': 945,
#  'jus': 946,
#  'staying': 947,
#  'serious': 948,
#  'ff': 949,
#  'load': 950,
#  'service': 951,
#  'website': 952,
#  'xoxo': 953,
#  'chillin': 954,
#  'interview': 955,
#  'taylor': 956,
#  'bag': 957,
#  '3d': 958,
#  'daddy': 959,
#  'space': 960,
#  'wolverine': 961,
#  'thru': 962,
#  'disappointed': 963,
#  'failed': 964,
#  'mcfly': 965,
#  'finger': 966,
#  '25': 967,
#  'door': 968,
#  'foot': 969,
#  'giving': 970,
#  'random': 971,
#  'proud': 972,
#  'wearing': 973,
#  'wheres': 974,
#  'waking': 975,
#  'twilight': 976,
#  'experience': 977,
#  'blood': 978,
#  'paper': 979,
#  '9': 980,
#  'games': 981,
#  'outta': 982,
#  'goodbye': 983,
#  'buying': 984,
#  'milk': 985,
#  'download': 986,
#  'pc': 987,
#  'peeps': 988,
#  'blackberry': 989,
#  'mobile': 990,
#  'apartment': 991,
#  'closed': 992,
#  'wednesday': 993,
#  'minute': 994,
#  'ny': 995,
#  'worked': 996,
#  'cheers': 997,
#  'prob': 998,
#  'cd': 999,
#  'sending': 1000,
#  ...}

# %%
train_sequences = tokenizer.texts_to_sequences(train_sentences)
val_sequences = tokenizer.texts_to_sequences(val_sentences)

# %%
print(train_sentences[10:15])
print(train_sequences[10:15])
# Out:
# ['much love hopeful reckon chances minimal p im never gonna get cake stuff', 'really really like song love story taylor swift', 'sharpie running dangerously low ink', 'want go music tonight lost voice', 'test test lg env2']
# [[34, 8, 2472, 2774, 3174, 8867, 495, 1, 88, 59, 4, 580, 218], [21, 21, 5, 190, 8, 659, 956, 2058], [8868, 415, 8869, 746, 5844], [28, 6, 206, 54, 185, 925], [460, 460, 4488, 8870]]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
max_length = 20
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding="post")
val_padded = pad_sequences(val_sequences, maxlen=max_length, padding="post")
train_padded.shape, val_padded.shape
# Out:
# ((21983, 20), (5497, 20))

# %%
train_padded[10]
# Out:
# array([  34,    8, 2472, 2774, 3174, 8867,  495,    1,   88,   59,    4,
#         580,  218,    0,    0,    0,    0,    0,    0,    0])

# %%
reverse_word_index = dict([(idx, word) for (word, idx) in word_index.items()])
def decode(sequence):
    return " ".join([reverse_word_index.get(idx, "?") for idx in sequence])

# %%
reverse_word_index
# Out:
# {1: 'im',
#  2: 'day',
#  3: 'good',
#  4: 'get',
#  5: 'like',
#  6: 'go',
#  7: 'dont',
#  8: 'love',
#  9: 'going',
#  10: 'today',
#  11: 'work',
#  12: 'got',
#  13: 'cant',
#  14: 'one',
#  15: 'happy',
#  16: 'lol',
#  17: 'know',
#  18: 'u',
#  19: 'time',
#  20: 'back',
#  21: 'really',
#  22: 'see',
#  23: 'well',
#  24: 'new',
#  25: 'home',
#  26: 'think',
#  27: 'night',
#  28: 'want',
#  29: 'mothers',
#  30: 'still',
#  31: 'thanks',
#  32: '2',
#  33: 'oh',
#  34: 'much',
#  35: 'great',
#  36: 'hope',
#  37: 'miss',
#  38: 'need',
#  39: 'last',
#  40: 'morning',
#  41: 'thats',
#  42: 'haha',
#  43: 'ill',
#  44: 'fun',
#  45: 'feel',
#  46: 'tomorrow',
#  47: 'twitter',
#  48: 'wish',
#  49: 'would',
#  50: 'didnt',
#  51: 'sad',
#  52: 'sorry',
#  53: 'bad',
#  54: 'tonight',
#  55: 'right',
#  56: 'week',
#  57: 'nice',
#  58: 'yeah',
#  59: 'gonna',
#  60: 'better',
#  61: 'make',
#  62: 'though',
#  63: 'way',
#  64: '3',
#  65: 'ive',
#  66: 'sleep',
#  67: 'come',
#  68: 'could',
#  69: 'weekend',
#  70: 'getting',
#  71: 'bed',
#  72: 'watching',
#  73: 'next',
#  74: 'people',
#  75: 'youre',
#  76: 'awesome',
#  77: 'wait',
#  78: 'school',
#  79: 'days',
#  80: 'hate',
#  81: 'say',
#  82: 'best',
#  83: 'thing',
#  84: 'yes',
#  85: 'even',
#  86: 'thank',
#  87: 'show',
#  88: 'never',
#  89: 'wont',
#  90: 'working',
#  91: 'ok',
#  92: 'cool',
#  93: 'long',
#  94: 'look',
#  95: 'little',
#  96: 'soon',
#  97: 'hey',
#  98: 'everyone',
#  99: 'done',
#  100: '4',
#  101: 'take',
#  102: 'friends',
#  103: 'us',
#  104: 'may',
#  105: 'mom',
#  106: 'wanna',
#  107: 'sure',
#  108: 'sick',
#  109: 'feeling',
#  110: 'life',
#  111: 'ur',
#  112: 'tired',
#  113: 'first',
#  114: 'another',
#  115: 'always',
#  116: 'already',
#  117: 'guys',
#  118: 'please',
#  119: 'doesnt',
#  120: 'movie',
#  121: 'phone',
#  122: 'house',
#  123: 'hours',
#  124: 'something',
#  125: 'watch',
#  126: 'trying',
#  127: 'find',
#  128: 'old',
#  129: 'ever',
#  130: 'man',
#  131: 'yet',
#  132: 'made',
#  133: 'went',
#  134: 'pretty',
#  135: 'looking',
#  136: 'friday',
#  137: 'ready',
#  138: 'x',
#  139: 'looks',
#  140: 'yay',
#  141: 'sucks',
#  142: 'bit',
#  143: 'thought',
#  144: 'girl',
#  145: 'follow',
#  146: 'guess',
#  147: 'away',
#  148: 'finally',
#  149: 'amazing',
#  150: 'big',
#  151: 'maybe',
#  152: 'left',
#  153: 'also',
#  154: 'live',
#  155: 'star',
#  156: 'omg',
#  157: 'ugh',
#  158: 'wow',
#  159: 'things',
#  160: '1',
#  161: 'friend',
#  162: 'saw',
#  163: 'missed',
#  164: 'let',
#  165: 'year',
#  166: 'start',
#  167: 'hot',
#  168: 'monday',
#  169: 'hear',
#  170: 'someone',
#  171: 'nothing',
#  172: 'hard',
#  173: 'keep',
#  174: 'said',
#  175: 'two',
#  176: 'around',
#  177: 'gone',
#  178: 'actually',
#  179: 'id',
#  180: 'tweet',
#  181: 'havent',
#  182: 'job',
#  183: 'early',
#  184: 'till',
#  185: 'lost',
#  186: 'hes',
#  187: 'check',
#  188: 'tell',
#  189: 'rain',
#  190: 'song',
#  191: 'later',
#  192: 'birthday',
#  193: 'car',
#  194: 'world',
#  195: 'try',
#  196: 'play',
#  197: 'glad',
#  198: 'ya',
#  199: 'bored',
#  200: 'baby',
#  201: 'cause',
#  202: 'help',
#  203: 'yesterday',
#  204: 'isnt',
#  205: 'found',
#  206: 'music',
#  207: 'since',
#  208: 'anything',
#  209: 'hair',
#  210: 'making',
#  211: 'talk',
#  212: 'makes',
#  213: 'waiting',
#  214: 'late',
#  215: 'n',
#  216: '5',
#  217: 'put',
#  218: 'stuff',
#  219: 'hi',
#  220: 'read',
#  221: 'sun',
#  222: 'lot',
#  223: 'family',
#  224: 'weather',
#  225: 'call',
#  226: 'almost',
#  227: 'hurts',
#  228: 'aww',
#  229: 'coming',
#  230: 'anyone',
#  231: 'least',
#  232: 'head',
#  233: 'excited',
#  234: 'moms',
#  235: 'lunch',
#  236: 'party',
#  237: 'summer',
#  238: 'many',
#  239: 'might',
#  240: 'must',
#  241: 'missing',
#  242: 'give',
#  243: 'leave',
#  244: 'gotta',
#  245: 'wasnt',
#  246: 'funny',
#  247: 'forward',
#  248: 'money',
#  249: 'whats',
#  250: 'poor',
#  251: 'everything',
#  252: 'believe',
#  253: 'end',
#  254: 'cute',
#  255: 'enjoy',
#  256: 'sounds',
#  257: 'sunday',
#  258: 'cold',
#  259: 'stop',
#  260: 'shes',
#  261: 'listening',
#  262: 'mean',
#  263: 'finished',
#  264: 'tho',
#  265: 'god',
#  266: 'use',
#  267: 'mine',
#  268: 'far',
#  269: 'without',
#  270: 'game',
#  271: 'coffee',
#  272: 'dinner',
#  273: 'wanted',
#  274: 'times',
#  275: 'buy',
#  276: 'totally',
#  277: 'eat',
#  278: 'thinking',
#  279: 'luck',
#  280: 'probably',
#  281: 'stupid',
#  282: 'couldnt',
#  283: 'welcome',
#  284: 'theres',
#  285: 'hour',
#  286: 'woke',
#  287: 'wants',
#  288: 'playing',
#  289: 'kids',
#  290: 'beautiful',
#  291: 'free',
#  292: 'enough',
#  293: 'okay',
#  294: 'followers',
#  295: 'sweet',
#  296: 'ha',
#  297: 'outside',
#  298: 'took',
#  299: 'weeks',
#  300: 'seen',
#  301: 'hell',
#  302: 'eating',
#  303: 'food',
#  304: 'w',
#  305: 'sooo',
#  306: 'hahaha',
#  307: 'years',
#  308: 'whole',
#  309: 'place',
#  310: 'room',
#  311: 'pic',
#  312: 'lovely',
#  313: 'came',
#  314: 'real',
#  315: 'stuck',
#  316: 'awww',
#  317: 'says',
#  318: 'following',
#  319: 'loved',
#  320: 'goodnight',
#  321: 'else',
#  322: 'hit',
#  323: 'office',
#  324: 'saturday',
#  325: 'taking',
#  326: 'anymore',
#  327: 'kinda',
#  328: '10',
#  329: 'girls',
#  330: 'book',
#  331: 'name',
#  332: 'every',
#  333: 'headache',
#  334: 'r',
#  335: 'tv',
#  336: 'online',
#  337: 'video',
#  338: 'forgot',
#  339: 'ago',
#  340: 'class',
#  341: 'super',
#  342: 'able',
#  343: 'used',
#  344: 'wars',
#  345: 'gets',
#  346: 'theyre',
#  347: 'holiday',
#  348: 'full',
#  349: 'wrong',
#  350: 'boo',
#  351: 'seems',
#  352: 'mind',
#  353: 'sitting',
#  354: 'alone',
#  355: 'busy',
#  356: 'stay',
#  357: 'dad',
#  358: 'talking',
#  359: 'hopefully',
#  360: 'internet',
#  361: 'minutes',
#  362: 'quite',
#  363: 'dude',
#  364: 'news',
#  365: 'seeing',
#  366: 'broke',
#  367: 'idea',
#  368: 'kind',
#  369: 'hello',
#  370: 'b',
#  371: 'guy',
#  372: 'called',
#  373: 'shopping',
#  374: 'trip',
#  375: 'either',
#  376: 'rest',
#  377: 'crazy',
#  378: 'iphone',
#  379: 'trek',
#  380: 'remember',
#  381: 'run',
#  382: 'mum',
#  383: 'post',
#  384: 'tweets',
#  385: '6',
#  386: 'part',
#  387: 'person',
#  388: 'dog',
#  389: 'fail',
#  390: 'tried',
#  391: 'cry',
#  392: 'meet',
#  393: 'break',
#  394: 'face',
#  395: 'evening',
#  396: 'cuz',
#  397: 'drink',
#  398: 'blog',
#  399: 'win',
#  400: 'lil',
#  401: 'bank',
#  402: 'soo',
#  403: 'lots',
#  404: 'lucky',
#  405: 'starting',
#  406: 'fine',
#  407: 'breakfast',
#  408: 'loves',
#  409: 'change',
#  410: 'ask',
#  411: 'ah',
#  412: 'hurt',
#  413: 'heard',
#  414: 'send',
#  415: 'running',
#  416: 'hoping',
#  417: 'til',
#  418: '7',
#  419: 'watched',
#  420: 'half',
#  421: 'goes',
#  422: 'computer',
#  423: 'ice',
#  424: 'ones',
#  425: 'pain',
#  426: 'writing',
#  427: 'wonderful',
#  428: 'instead',
#  429: 'site',
#  430: 'boy',
#  431: 'lets',
#  432: 'turn',
#  433: 'mommy',
#  434: 'needs',
#  435: 'soooo',
#  436: 'sleeping',
#  437: 'heading',
#  438: 'true',
#  439: 'btw',
#  440: 'youtube',
#  441: 'perfect',
#  442: 'bought',
#  443: 'high',
#  444: 'hehe',
#  445: 'aw',
#  446: 'beach',
#  447: 'told',
#  448: 'tea',
#  449: 'picture',
#  450: 'feels',
#  451: 'started',
#  452: 'raining',
#  453: 'tickets',
#  454: 'lmao',
#  455: 'bday',
#  456: 'shower',
#  457: 'definitely',
#  458: 'awake',
#  459: '8',
#  460: 'test',
#  461: 'fan',
#  462: 'favorite',
#  463: 'email',
#  464: 'drive',
#  465: 'couple',
#  466: 'moment',
#  467: 'move',
#  468: 'heart',
#  469: 'supposed',
#  470: 'concert',
#  471: 'goin',
#  472: 'wake',
#  473: 'month',
#  474: 'boring',
#  475: 'aint',
#  476: 'arent',
#  477: 'mother',
#  478: 'link',
#  479: 'suck',
#  480: 'cleaning',
#  481: 'facebook',
#  482: 'account',
#  483: 'dead',
#  484: 'anyway',
#  485: 'comes',
#  486: 'wishing',
#  487: 'pictures',
#  488: 'yall',
#  489: 'care',
#  490: 'cat',
#  491: 'sigh',
#  492: 'interesting',
#  493: 'asleep',
#  494: 'set',
#  495: 'p',
#  496: 'fell',
#  497: 'means',
#  498: 'sometimes',
#  499: 'happen',
#  500: 'months',
#  501: 'final',
#  502: 'drinking',
#  503: 'water',
#  504: 'yea',
#  505: 'problem',
#  506: 'text',
#  507: 'nite',
#  508: 'jonas',
#  509: 'top',
#  510: 'happened',
#  511: 'sadly',
#  512: 'rock',
#  513: 'close',
#  514: 'exam',
#  515: 'leaving',
#  516: 'tour',
#  517: '12',
#  518: 'movies',
#  519: 'fast',
#  520: 'reading',
#  521: 'la',
#  522: 'dear',
#  523: 'red',
#  524: 'flu',
#  525: 'hang',
#  526: 'vote',
#  527: 'hungry',
#  528: 'june',
#  529: 'sunny',
#  530: '4th',
#  531: 'ppl',
#  532: 'course',
#  533: 'season',
#  534: 'bout',
#  535: 'catch',
#  536: 'songs',
#  537: 'short',
#  538: 'meeting',
#  539: 'youll',
#  540: 'boys',
#  541: 'chocolate',
#  542: 'less',
#  543: 'dream',
#  544: 'pics',
#  545: 'open',
#  546: 'bring',
#  547: 'park',
#  548: 'moving',
#  549: 'using',
#  550: 'afternoon',
#  551: 'spend',
#  552: 'list',
#  553: 'due',
#  554: 'past',
#  555: 'write',
#  556: 'fb',
#  557: 'brothers',
#  558: 'seriously',
#  559: 'date',
#  560: 'eyes',
#  561: 'mad',
#  562: 'gave',
#  563: 'city',
#  564: 'ipod',
#  565: 'unfortunately',
#  566: 'episode',
#  567: 'worth',
#  568: 'everybody',
#  569: 'sound',
#  570: 'second',
#  571: 'cut',
#  572: 'cream',
#  573: 'sore',
#  574: 'youve',
#  575: 'driving',
#  576: '30',
#  577: 'together',
#  578: 'knew',
#  579: 'enjoying',
#  580: 'cake',
#  581: 'jealous',
#  582: 'forget',
#  583: 'yep',
#  584: 'fair',
#  585: 'london',
#  586: '1st',
#  587: 'reason',
#  588: 'wedding',
#  589: 'xd',
#  590: 'plus',
#  591: 'card',
#  592: 'liked',
#  593: 'nap',
#  594: 'works',
#  595: 'exams',
#  596: 'garden',
#  597: 'looked',
#  598: 'meant',
#  599: 'learn',
#  600: 'agree',
#  601: 'plans',
#  602: 'weird',
#  603: 'broken',
#  604: 'saying',
#  605: 'hugs',
#  606: 'apparently',
#  607: 'wouldnt',
#  608: 'ride',
#  609: 'uk',
#  610: 'congrats',
#  611: 'mood',
#  612: 'warm',
#  613: 'photo',
#  614: 'easy',
#  615: 'chance',
#  616: 'worst',
#  617: 'spent',
#  618: 'page',
#  619: 'sent',
#  620: 'bus',
#  621: 'message',
#  622: 'ahh',
#  623: 'special',
#  624: 'rather',
#  625: 'reply',
#  626: 'english',
#  627: 'walk',
#  628: 'nope',
#  629: 'huge',
#  630: 'died',
#  631: 'windows',
#  632: 'side',
#  633: 'em',
#  634: 'figure',
#  635: 'yummy',
#  636: 'sat',
#  637: 'photos',
#  638: 'sister',
#  639: 'point',
#  640: 'wtf',
#  641: 'except',
#  642: 'finish',
#  643: 'gym',
#  644: 'babe',
#  645: 'da',
#  646: 'bye',
#  647: 'lady',
#  648: 'town',
#  649: 'add',
#  650: 'tweeting',
#  651: 'fall',
#  652: 'yum',
#  653: 'clean',
#  654: 'different',
#  655: 'c',
#  656: 'loving',
#  657: 'kid',
#  658: 'earlier',
#  659: 'story',
#  660: 'slept',
#  661: 'drunk',
#  662: 'black',
#  663: 'worry',
#  664: 'word',
#  665: 'longer',
#  666: 'google',
#  667: 'store',
#  668: 'fact',
#  669: 'ohh',
#  670: 'beer',
#  671: 'business',
#  672: 'save',
#  673: 'hates',
#  674: 'bet',
#  675: 'especially',
#  676: 'understand',
#  677: 'pizza',
#  678: 'hanging',
#  679: 'needed',
#  680: 'listen',
#  681: 'album',
#  682: 'living',
#  683: 'shame',
#  684: 'exciting',
#  685: 'dreams',
#  686: 'shows',
#  687: 'seem',
#  688: 'wear',
#  689: 'absolutely',
#  690: 'bless',
#  691: 'sold',
#  692: 'laptop',
#  693: '100',
#  694: 'pick',
#  695: 'study',
#  696: 'die',
#  697: 'wishes',
#  698: 'officially',
#  699: 'parents',
#  700: 'forever',
#  701: '15',
#  702: 'chat',
#  703: 'starts',
#  704: 'chicken',
#  705: 'update',
#  706: 'fans',
#  707: 'visit',
#  708: 'white',
#  709: 'club',
#  710: 'ran',
#  711: 'mums',
#  712: 'throat',
#  713: 'three',
#  714: '20',
#  715: 'thx',
#  716: 'ate',
#  717: 'relaxing',
#  718: 'ps',
#  719: 'smile',
#  720: 'camera',
#  721: 'brother',
#  722: 'answer',
#  723: 'bgt',
#  724: 'along',
#  725: 'hows',
#  726: 'played',
#  727: 'nights',
#  728: 'happens',
#  729: 'updates',
#  730: 'ahhh',
#  731: 'graduation',
#  732: 'hand',
#  733: 'mr',
#  734: 'apple',
#  735: 'fantastic',
#  736: 'company',
#  737: 'idk',
#  738: 'sign',
#  739: 'wondering',
#  740: 'college',
#  741: 'hmm',
#  742: 'near',
#  743: 'horrible',
#  744: 'cos',
#  745: 'taken',
#  746: 'low',
#  747: 'keeps',
#  748: 'plan',
#  749: 'small',
#  750: 'inside',
#  751: 'cannot',
#  752: 'dang',
#  753: 'prom',
#  754: 'quick',
#  755: 'sunshine',
#  756: 'stomach',
#  757: 'bike',
#  758: 'slow',
#  759: 'middle',
#  760: 'exactly',
#  761: 'project',
#  762: 'fingers',
#  763: 'shall',
#  764: 'band',
#  765: 'packing',
#  766: 'join',
#  767: 'church',
#  768: 'dance',
#  769: 'itll',
#  770: 'cup',
#  771: 'behind',
#  772: 'line',
#  773: 'revision',
#  774: 'hug',
#  775: 'via',
#  776: 'etc',
#  777: 'hun',
#  778: 'fly',
#  779: 'hahah',
#  780: 'traffic',
#  781: 'sleepy',
#  782: 'screen',
#  783: 'film',
#  784: 'usually',
#  785: 'radio',
#  786: 'shoes',
#  787: 'completely',
#  788: 'lazy',
#  789: 'shop',
#  790: 'snl',
#  791: 'bbq',
#  792: 'dress',
#  793: 'upset',
#  794: '11',
#  795: 'front',
#  796: 'green',
#  797: 'team',
#  798: 'wine',
#  799: 'none',
#  800: 'huh',
#  801: 'son',
#  802: 'homework',
#  803: 'pass',
#  804: 'realized',
#  805: 'messages',
#  806: 'version',
#  807: 'woo',
#  808: 'air',
#  809: 'feet',
#  810: 'quiet',
#  811: 'train',
#  812: 'although',
#  813: 'body',
#  814: 'crying',
#  815: 'wife',
#  816: 'gutted',
#  817: 'lame',
#  818: 'dvd',
#  819: 'ooh',
#  820: 'words',
#  821: 'problems',
#  822: 'single',
#  823: 'rainy',
#  824: 'app',
#  825: 'hospital',
#  826: 'ouch',
#  827: 'safe',
#  828: 'pool',
#  829: 'luv',
#  830: 'bc',
#  831: 'sit',
#  832: 'met',
#  833: 'mama',
#  834: 'lonely',
#  835: 'thinks',
#  836: 'hubby',
#  837: 'dm',
#  838: 'starbucks',
#  839: 'blue',
#  840: 'moved',
#  841: 'takes',
#  842: 'number',
#  843: 'math',
#  844: 'july',
#  845: 'appreciate',
#  846: 'nyc',
#  847: 'wonder',
#  848: 'decided',
#  849: 'worse',
#  850: 'followed',
#  851: 'shirt',
#  852: 'felt',
#  853: 'others',
#  854: 'k',
#  855: 'boyfriend',
#  856: 'singing',
#  857: 'clothes',
#  858: 'men',
#  859: 'vegas',
#  860: 'rip',
#  861: 'question',
#  862: 'mac',
#  863: 'airport',
#  864: 'gift',
#  865: 'tuesday',
#  866: 'cheese',
#  867: 'ima',
#  868: 'tummy',
#  869: 'case',
#  870: 'miles',
#  871: 'annoying',
#  872: 'comment',
#  873: 'french',
#  874: 'whatever',
#  875: 'mention',
#  876: 'ended',
#  877: 'flight',
#  878: 'feelin',
#  879: 'kill',
#  880: 'support',
#  881: 'enjoyed',
#  882: 'posted',
#  883: 'thursday',
#  884: 'checked',
#  885: 'justin',
#  886: 'share',
#  887: 'swine',
#  888: 'somewhere',
#  889: 'videos',
#  890: 'dancing',
#  891: 'min',
#  892: 'yo',
#  893: 'currently',
#  894: 'sing',
#  895: 'extra',
#  896: 'ticket',
#  897: 'dads',
#  898: 'matter',
#  899: 'beat',
#  900: '2day',
#  901: 'walking',
#  902: 'fix',
#  903: 'fam',
#  904: 'mate',
#  905: 'spending',
#  906: 'john',
#  907: 'legs',
#  908: 'alot',
#  909: 'classes',
#  910: 'race',
#  911: 'alright',
#  912: 'public',
#  913: 'hannah',
#  914: 'guitar',
#  915: 'studying',
#  916: 'bloody',
#  917: 'become',
#  918: 'sexy',
#  919: 'paid',
#  920: 'tom',
#  921: 'dark',
#  922: 'ages',
#  923: 'bummed',
#  924: 'bro',
#  925: 'voice',
#  926: 'available',
#  927: 'round',
#  928: 'itunes',
#  929: 'group',
#  930: 'suppose',
#  931: 'l',
#  932: 'fixed',
#  933: 'lately',
#  934: 'follower',
#  935: 'gorgeous',
#  936: 'gig',
#  937: 'dogs',
#  938: 'tonite',
#  939: 'likes',
#  940: 'moon',
#  941: 'afraid',
#  942: 'followfriday',
#  943: 'web',
#  944: 'count',
#  945: 'deal',
#  946: 'jus',
#  947: 'staying',
#  948: 'serious',
#  949: 'ff',
#  950: 'load',
#  951: 'service',
#  952: 'website',
#  953: 'xoxo',
#  954: 'chillin',
#  955: 'interview',
#  956: 'taylor',
#  957: 'bag',
#  958: '3d',
#  959: 'daddy',
#  960: 'space',
#  961: 'wolverine',
#  962: 'thru',
#  963: 'disappointed',
#  964: 'failed',
#  965: 'mcfly',
#  966: 'finger',
#  967: '25',
#  968: 'door',
#  969: 'foot',
#  970: 'giving',
#  971: 'random',
#  972: 'proud',
#  973: 'wearing',
#  974: 'wheres',
#  975: 'waking',
#  976: 'twilight',
#  977: 'experience',
#  978: 'blood',
#  979: 'paper',
#  980: '9',
#  981: 'games',
#  982: 'outta',
#  983: 'goodbye',
#  984: 'buying',
#  985: 'milk',
#  986: 'download',
#  987: 'pc',
#  988: 'peeps',
#  989: 'blackberry',
#  990: 'mobile',
#  991: 'apartment',
#  992: 'closed',
#  993: 'wednesday',
#  994: 'minute',
#  995: 'ny',
#  996: 'worked',
#  997: 'cheers',
#  998: 'prob',
#  999: 'cd',
#  1000: 'sending',
#  ...}

# %%
def decode(sequence):
    return " ".join([reverse_word_index.get(idx, "?") for idx in sequence])

# %%
decoded_text = decode(train_sequences[10])

print(train_sequences[10])
print(decoded_text)
# Out:
# [34, 8, 2472, 2774, 3174, 8867, 495, 1, 88, 59, 4, 580, 218]
# much love hopeful reckon chances minimal p im never gonna get cake stuff

# %%
from tensorflow.keras import layers
model = keras.models.Sequential()
model.add(layers.Embedding(num_unique_words, 32, input_length=max_length))
model.add(layers.LSTM(64, dropout=0.1))
model.add(layers.Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 32)            888736
#
#  lstm (LSTM)                 (None, 64)                24832
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 913763 (3.49 MB)
# Trainable params: 913763 (3.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss = keras.losses.SparseCategoricalCrossentropy()
optim = keras.optimizers.Adam(learning_rate=0.001)
metrics = ["accuracy"]
model.compile(loss=loss, optimizer=optim, metrics=metrics)

# %%
sentiment_mapping = {"neutral": 0, "positive": 1, "negative": 2}
train_labels = np.array([sentiment_mapping[label] for label in train_labels])
val_labels = np.array([sentiment_mapping[label] for label in val_labels])

# %%
train_labels = train_labels[:-1]

# %%
model.fit(train_padded, train_labels, epochs=20, validation_data=(val_padded, val_labels), verbose=2)
# Out:
# Epoch 1/20
# 687/687 - 25s - loss: 1.0883 - accuracy: 0.4022 - val_loss: 1.0861 - val_accuracy: 0.4128 - 25s/epoch - 36ms/step
# Epoch 2/20
# 687/687 - 15s - loss: 1.0713 - accuracy: 0.4203 - val_loss: 1.1035 - val_accuracy: 0.3882 - 15s/epoch - 22ms/step
# Epoch 3/20
# 687/687 - 21s - loss: 0.9292 - accuracy: 0.5502 - val_loss: 1.2283 - val_accuracy: 0.3593 - 21s/epoch - 31ms/step
# Epoch 4/20
# 687/687 - 18s - loss: 0.7034 - accuracy: 0.6974 - val_loss: 1.4056 - val_accuracy: 0.3682 - 18s/epoch - 26ms/step
# Epoch 5/20
# 687/687 - 20s - loss: 0.5443 - accuracy: 0.7648 - val_loss: 1.5928 - val_accuracy: 0.3673 - 20s/epoch - 29ms/step
# Epoch 6/20
# 687/687 - 20s - loss: 0.4476 - accuracy: 0.8038 - val_loss: 1.8225 - val_accuracy: 0.3391 - 20s/epoch - 28ms/step
# Epoch 7/20
# 687/687 - 18s - loss: 0.3855 - accuracy: 0.8259 - val_loss: 1.8534 - val_accuracy: 0.3551 - 18s/epoch - 26ms/step
# Epoch 8/20
# 687/687 - 19s - loss: 0.3420 - accuracy: 0.8426 - val_loss: 2.3056 - val_accuracy: 0.3589 - 19s/epoch - 28ms/step
# Epoch 9/20
# 687/687 - 19s - loss: 0.3185 - accuracy: 0.8511 - val_loss: 2.4071 - val_accuracy: 0.3578 - 19s/epoch - 28ms/step
# Epoch 10/20
# 687/687 - 15s - loss: 0.2948 - accuracy: 0.8614 - val_loss: 2.6475 - val_accuracy: 0.3620 - 15s/epoch - 22ms/step
# Epoch 11/20
# 687/687 - 13s - loss: 0.2775 - accuracy: 0.8707 - val_loss: 2.3148 - val_accuracy: 0.3635 - 13s/epoch - 19ms/step
# Epoch 12/20
# 687/687 - 13s - loss: 0.2619 - accuracy: 0.8759 - val_loss: 2.9000 - val_accuracy: 0.3555 - 13s/epoch - 19ms/step
# Epoch 13/20
# 687/687 - 13s - loss: 0.2488 - accuracy: 0.8816 - val_loss: 2.6595 - val_accuracy: 0.3602 - 13s/epoch - 19ms/step
# Epoch 14/20
# 687/687 - 15s - loss: 0.2406 - accuracy: 0.8859 - val_loss: 2.7673 - val_accuracy: 0.3578 - 15s/epoch - 22ms/step
# Epoch 15/20
# 687/687 - 14s - loss: 0.2287 - accuracy: 0.8909 - val_loss: 3.0864 - val_accuracy: 0.3664 - 14s/epoch - 21ms/step
# Epoch 16/20
# 687/687 - 14s - loss: 0.2218 - accuracy: 0.8948 - val_loss: 2.9324 - val_accuracy: 0.3556 - 14s/epoch - 21ms/step
# Epoch 17/20
# 687/687 - 13s - loss: 0.2130 - accuracy: 0.8973 - val_loss: 3.1335 - val_accuracy: 0.3564 - 13s/epoch - 19ms/step
# Epoch 18/20
# 687/687 - 13s - loss: 0.2089 - accuracy: 0.8976 - val_loss: 3.1273 - val_accuracy: 0.3576 - 13s/epoch - 20ms/step
# Epoch 19/20
# 687/687 - 13s - loss: 0.1999 - accuracy: 0.9038 - val_loss: 3.3650 - val_accuracy: 0.3580 - 13s/epoch - 19ms/step
# Epoch 20/20
# 687/687 - 13s - loss: 0.1981 - accuracy: 0.9051 - val_loss: 3.2095 - val_accuracy: 0.3396 - 13s/epoch - 19ms/step

# %%
predictions = model.predict(train_padded)
predicted_labels = [np.argmax(pred) for pred in predictions]
# Out:
# 687/687 [==============================] - 4s 5ms/step

# %%
everse_sentiment_mapping = {v: k for k, v in sentiment_mapping.items()}
predicted_labels = [reverse_sentiment_mapping[label] for label in predicted_labels]

# %%
print(train_sentences[10:20])
print(train_labels[10:20])
print(predicted_labels[10:20])
# Out:
# ['much love hopeful reckon chances minimal p im never gonna get cake stuff', 'really really like song love story taylor swift', 'sharpie running dangerously low ink', 'want go music tonight lost voice', 'test test lg env2', 'uh oh sunburned', 'sok trying plot alternatives speak sigh', 'ive sick past days thus hair looks wierd didnt hat would look', 'back home gonna miss every one', 'hes']
# [0 1 2 2 0 2 2 2 2 0]
# ['neutral', 'positive', 'negative', 'neutral', 'neutral', 'neutral', 'negative', 'negative', 'neutral', 'neutral']
